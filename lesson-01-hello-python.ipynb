# %% [markdown]
# # 🎉 Lesson 1: Hello Python!
#
# Welcome to your first Python lesson! Today you're going to learn how to make the computer talk to you. It's like magic!
#
# ## What is Python?
#
# Python is a special language that helps us talk to computers. Just like you speak English to talk to people, we use Python to tell computers what to do!
#
# Think of it like giving instructions to a friendly robot. When you tell the robot what to do, it listens and does exactly what you say!

# %% [markdown]
# ## 👋 Your First Python Command: print()
#
# The `print()` command is like asking the computer to say something out loud (but it shows it on the screen instead).
#
# Let's try it! Click the play button (▶️) below to run the code:

# %% [markdown]
# ## 🎓 What You Learned Today!
#
# Great job! Today you learned:
# - ✅ How to use the `print()` command
# - ✅ How to make the computer display messages
# - ✅ How to create simple art with text
#
# **Next lesson:** We'll learn about Math Magic! 🔢✨
#
# Remember: Programming is like playing! Have fun and experiment!

# %%
# This is your first Python program!
print("Hello, World!")
print("My name is Owen!")
print("I am learning Python!")

# %% [markdown]
# ## 🤔 What Just Happened?
#
# When you pressed play, the computer read your instructions and showed the messages on the screen!
#
# - The word `print` tells Python "show this message"
# - The quotation marks `" "` are like a box that holds your message
# - Python reads it and displays it for you!

# %% [markdown]
# ## ✏️ Now You Try!
#
# Can you make the computer say YOUR name? Edit the code below and add your own messages!
#
# **Try these ideas:**
# - Make the computer say your favorite food
# - Tell it about your favorite animal
# - Make it say something funny!

# %%
# Edit this code! Change it to say what YOU want!
print("Add your message here!")

# %% [markdown]
# ## 🎨 Let's Make a Picture with Words!
#
# You can use special characters to draw pictures. Look at this!

# %%
# Drawing with words!
print("  ^_^  ")
print(" /   \\ ")
print("|  o  |")
print(" \\___/ ")
print("This is a robot!")

# %% [markdown]
# ## 🌟 Super Challenge!
#
# Can you create your own picture using print statements? Try making:
# - A house
# - A tree
# - Your own robot
# - Anything you can imagine!
#
# Use the code box below to draw your picture!

# %%
# Your turn to draw! Make your own picture here!
print("Start drawing here!")
